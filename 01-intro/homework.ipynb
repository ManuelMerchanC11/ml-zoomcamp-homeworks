# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Q1. Pandas version
#
# What version of Pandas did you install?

# %%
pd.__version__
# Out:
# '3.0.6'

# %% [markdown]
# ## Getting Data

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Out:
# --2026-09-22 18:24:13--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 635180 (620K) [text/plain]
# Saving to: ‘car_fuel_efficiency_2026.csv’
#
# car_fuel_efficiency 100%[===================>] 620.29K  --.-KB/s    in 0.02s
#
# 2026-09-22 18:24:13 (33.1 MB/s) - ‘car_fuel_efficiency_2026.csv’ saved [635180/635180]

# %%
df = pd.read_csv('car_fuel_efficiency_2026.csv')
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# 4          17.5                 31.0

# %% [markdown]
# ## Q2. Records count
# How many records are in the dataset?

# %%
df.shape
# Out:
# (10000, 11)

# %% [markdown]
# ## Q3. Fuel types
# How many fuel types are presented in the dataset?

# %%
df['fuel_type'].describe()
# Out:
# count        10000
# unique           3
# top       Gasoline
# freq          6913
# Name: fuel_type, dtype: object

# %% [markdown]
# ## Q4. Missing values
# How many columns in the dataset have missing values?
